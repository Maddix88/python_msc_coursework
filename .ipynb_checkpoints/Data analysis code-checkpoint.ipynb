# %% [markdown]
# # Code for data analysis section of python coursework

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import FreqDist
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy.stats import probplot
import string
import re
from nltk.stem import WordNetLemmatizer
# %matplotlib inline

# %% [markdown]
# ## Load in the data

# %%
df = pd.read_csv("opencritic_data_cleaned.csv", index_col = "Unnamed: 0")

df.head()

df.dropna(inplace=True)

df.head()
# Out:
#                 name               developer         publisher genre  \
# 0  The Outer Worlds   Obsidian Entertainment  Private Division   RPG
# 1  The Outer Worlds   Obsidian Entertainment  Private Division   RPG
# 3  The Outer Worlds   Obsidian Entertainment  Private Division   RPG
# 4  The Outer Worlds   Obsidian Entertainment  Private Division   RPG
# 6  The Outer Worlds   Obsidian Entertainment  Private Division   RPG
#
#   release_date                                        description  \
# 0   2019-10-25  The Outer Worlds is a new single-player first-...
# 1   2019-10-25  The Outer Worlds is a new single-player first-...
# 3   2019-10-25  The Outer Worlds is a new single-player first-...
# 4   2019-10-25  The Outer Worlds is a new single-player first-...
# 6   2019-10-25  The Outer Worlds is a new single-player first-...
#
#    critics_average_score                                      critic_review  \
# 0                     82  There's a category of games I think of as Satu...
# 1                     82  With The Outer Worlds, Obsidian has found its ...
# 3                     82  A deep, funny, and intricately designed RPG re...
# 4                     82  The Outer Worlds marks Obsidian operating at t...
# 6                     82  Classic RPG sensibilities enhance wonderful ch...
#
#         date_of_review  critics_score
# 0  2019-10-22 00:00:00           79.0
# 1  2019-10-22 00:00:00           85.0
# 3  2019-10-29 00:00:00           90.0
# 4  2019-10-22 00:00:00           90.0
# 6  2019-10-22 00:00:00           93.0

# %%
df.iloc[5,7]
# Out:
# 'Obsidian has pulled off the delicate task of creating an RPG that feels big while still keeping control of the overall scope of the game itself.'

# %% [markdown]
# ## Research questions to ask of the data
#
# ### This section is before the sentiment analysis model implementation using Naive Bayes and Support Vector Machines (SVM)

# %% [markdown]
# ### Research question 1:
#
# ### What is the correlation between review length and critics scores?

# %%
def process_text(text):
    """
    Converts text to lower case, removes all punctuation and finally performed tokenisation

    """
    #apply lowercase
    lower_case_text = text.lower()
    #remove punctuation
    punctuation = string.punctuation
    punc_removed_text = ""
    for letter in lower_case_text:
        if letter not in punctuation:
            punc_removed_text += letter
            
    #tokenise the text
    tokenised = word_tokenize(punc_removed_text)
    
    #remove stop words
    stop_words= stopwords.words("english")
    new_text = []
    for t in tokenised:
        if t not in stop_words:
            new_text.append(t)
    
    #get rid of apostrophe doesn't go when punctuation is removed
    while '’' in new_text:
        new_text.remove('’')
        
    #get rid of numbers
    pattern = r'[\d]+'
    numbers_removed = [re.sub(pattern, "", w) for w in new_text]
    while "" in numbers_removed:
        numbers_removed.remove("")
    
    #lemmatize each word
    lem = WordNetLemmatizer()
    text_lemmatized = [lem.lemmatize(word) for word in numbers_removed]
    
    return text_lemmatized

def process_word(word):
    """
    Converts word to lower case, removes all punctuation and strips any spaces

    """
    #convert word to lowercase
    lower_case = word.lower()
    
    #remove punctuation
    punctuation = string.punctuation
    punc_removed = ''
    for letter in lower_case:
        if letter not in punctuation:
            punc_removed += letter
    
    #strip spaces on either side of the word
    word_stripped = punc_removed.lstrip().rstrip()
    
    return word_stripped

# %%
df2 = df.copy()
#making a copy --> https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#drop null values from critic review and scritics score
df2.dropna(subset=['critic_review', 'critics_score'], inplace=True)

#df2.info() critic_review is an object and critics_score is a float, which are the correct data types

df_q1 = df2.loc[:,['critic_review', 'critics_score']]
#df_q1

#get length of each review by creating a new column with the length of the review
#use process_text function to clean text


df_q1['review_tokenize'] = df_q1.loc[:,'critic_review'].apply(lambda x: process_text(x))

#get length of each review
df_q1['review_length'] = df_q1.loc[:,'review_tokenize'].apply(len)
df_q1
# Out:
#                                            critic_review  critics_score  \
# 0      There's a category of games I think of as Satu...           79.0
# 1      With The Outer Worlds, Obsidian has found its ...           85.0
# 3      A deep, funny, and intricately designed RPG re...           90.0
# 4      The Outer Worlds marks Obsidian operating at t...           90.0
# 6      Classic RPG sensibilities enhance wonderful ch...           93.0
# ...                                                  ...            ...
# 15080  Star Wars Battlefront 2 manages to make nearly...           40.0
# 15081  An engaging campaign, a satisfying arcade mode...           80.0
# 15083  Star Wars Battlefront II is a complete experie...           85.0
# 15084  I do really enjoy playing this, but when you l...           70.0
# 15085  So, does Star Wars Battlefront II fulfill the ...           65.0
#
#                                          review_tokenize  review_length
# 0      [there, category, game, think, saturday, morni...             32
# 1      [outer, world, obsidian, found, path, space, b...             11
# 3      [deep, funny, intricately, designed, rpg, remi...             16
# 4      [outer, world, mark, obsidian, operating, top,...             14
# 6      [classic, rpg, sensibility, enhance, wonderful...             14
# ...                                                  ...            ...
# 15080  [star, war, battlefront, manages, make, nearly...             48
# 15081  [engaging, campaign, satisfying, arcade, mode,...             25
# 15083  [star, war, battlefront, ii, complete, experie...             40
# 15084  [really, enjoy, playing, look, aspect, could, ...             11
# 15085  [star, war, battlefront, ii, fulfill, star, wa...             46
#
# [6687 rows x 4 columns]

# %%
#statistics for question 1

#mediann and mean review length: there are some outliers as the mean is greater than the median
median_review_length = np.median(df_q1['review_length'])
mean_review_length = np.mean(df_q1['review_length'])
max_review_length = max(df_q1['review_length'])
min_review_length = min(df_q1['review_length'])

#mean and median critics scores
mean_review_score = np.mean(df_q1['critics_score'])
median_review_score = np.median(df_q1['critics_score'])
max_review_score = max(df_q1['critics_score'])
min_review_score = min(df_q1['critics_score'])

stats_table = pd.DataFrame(data={
    'Mean':[round(mean_review_length, 2), round(mean_review_score, 2)], 
    'Median': [median_review_length, median_review_score],
    'Maximum': [max_review_length, max_review_score],
    'Minimum': [min_review_length, min_review_score],
    }, index=['review_length','critics_score'])
                                
stats_table
# Out:
#                 Mean  Median  Maximum  Minimum
# review_length  26.79    23.0    178.0      1.0
# critics_score  82.24    85.0    100.0     15.0

# %% [markdown]
# According to the statistics Dataframe, the review length seems to be skewed towards the maximum, while the critics score is skewed towards the minimum score, hence possible outliers towards the maximum review length and minimum critics score

# %%
#plot subplots with review length boxplot, critics_score histogram and joint scatterplot for both variables

fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(20,5))
#plot review_length as a boxplot
axs[0].boxplot(x=df_q1['review_length'], showmeans=True, meanline=True)
axs[0].set_title('Boxplot displaying the review length of each review, \nbased on number of words.')
axs[0].set_xticklabels('')
axs[0].set_ylabel('Review length by word count')

#plot critics_score
#plot QQ plot too to show skewness
#and plot axvline on histogram (page 100 stats book for help)
axs[1].hist(df_q1['critics_score'], bins=14, color='springgreen')
axs[1].set_title('Histogram of critics scores\n (mean critics score represented by the black line)')
axs[1].set_xlabel('Critics scores')
axs[1].set_ylabel('Frequency')
axs[1].axvline(x=mean_review_score, color='black')

axs[2].scatter(df_q1['critics_score'], df_q1['review_length'])
axs[2].set_title('Comparative histogram between review length\n and critic scores.')
axs[2].set_xlabel('Critics scores')
axs[2].set_ylabel('Review length by word count')
axs[2].axvline(x=mean_review_score, color='black')
axs[2].axhline(y=mean_review_length, color='black')

plt.show()

# %%
#plot QQ plot for each of the two variables to show presence of skewness
#standardise the variables to make the x and y axis similar in scale

df_q1['normalise_review_length'] = (df_q1['review_length'] - np.mean(df_q1['review_length'])) / np.std(df_q1['review_length'])
df_q1['normalise_critics_score'] = (df_q1['critics_score'] - np.mean(df_q1['critics_score'])) / np.std(df_q1['critics_score'])

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(20,5))
probplot(df_q1['normalise_review_length'], plot=axs[0])
axs[0].set_ylabel('Length of review by word count.')
axs[0].set_title('Length of review by word count.')
probplot(df_q1['normalise_critics_score'], plot=axs[1])

plt.show()

#refer to page 71 of stats book to explain skewness

# %% [markdown]
# ### Research question 2:
#
# ### How many reviews per game and does this number correlate with the average critics score?

# %%
#make a copy of original dataframe
df3 = df.copy()

#df3.head()

df_q2_review_count = df3.groupby('name').critic_review.count()
df_q2_ave_critic_score = df3.groupby('name').critics_average_score.mean()

df_q2 = pd.concat([df_q2_review_count, df_q2_ave_critic_score], axis=1)
df_q2
# Out:
#                                         critic_review  critics_average_score
# name
#  Call of Cthulhu                                  113                   67.0
#  Call of Duty: WWII                               120                   78.0
#  Crash Bandicoot N. Sane Trilogy                  119                   80.0
#  Deus Ex: Mankind Divided                          93                   82.0
#  Donkey Kong Country: Tropical Freeze             103                   85.0
#  Doom                                             100                   86.0
#  Gears of War 4                                   106                   84.0
#  Horizon Zero Dawn                                125                   89.0
#  Maneater                                         124                   71.0
#  Mass Effect Andromeda                            127                   72.0
#  Prey                                             120                   81.0
#  Star Wars Battlefront 2                           96                   68.0
# A Plague Tale: Innocence                          116                   81.0
# Assassin's Creed Odyssey                          117                   84.0
# Assassin's Creed Origins                          130                   85.0
# Biomutant                                         124                   67.0
# Call of Duty: Black Ops Cold War                  104                   76.0
# Call of Duty: Modern Warfare                      108                   81.0
# Control                                           130                   84.0
# Crash Bandicoot 4: It's About Time                130                   85.0
# Cyberpunk 2077                                    129                   76.0
# DOOM Eternal                                      143                   89.0
# Dark Souls III                                    115                   90.0
# Darksiders Genesis                                110                   79.0
# Destiny 2                                         134                   84.0
# Dishonored 2                                       99                   86.0
# Dragon Ball FighterZ                              101                   86.0
# Fallout 76                                        108                   53.0
# Far Cry 5                                         133                   82.0
# Forza Horizon 4                                   102                   92.0
# Gears 5                                           100                   85.0
# Ghost of Tsushima                                 132                   85.0
# God of War                                        131                   95.0
# Hitman 2                                          102                   83.0
# Immortals Fenyx Rising                            113                   79.0
# Injustice 2                                       118                   87.0
# Little Nightmares II                              118                   83.0
# Marvel's Avengers                                 128                   68.0
# Marvel's Spider-Man                               122                   88.0
# Marvel's Spider-Man: Miles Morales                112                   85.0
# Metro Exodus                                      120                   83.0
# Middle-earth: Shadow of War                       117                   82.0
# Mortal Kombat 11                                  117                   82.0
# Resident Evil Village                             127                   84.0
# Shadow of the Tomb Raider                         120                   80.0
# Spyro Reignited Trilogy                           110                   81.0
# The Evil Within 2                                 117                   80.0
# The Last of Us Part II                            143                   93.0
# The Outer Worlds                                  150                   82.0
# The Sinking City                                  121                   69.0
# Titanfall 2                                        95                   87.0
# Tom Clancy's The Division 2                       117                   83.0
# Tony Hawk's Pro Skater 1 + 2                      134                   89.0
# Uncharted: The Lost Legacy                        101                   85.0
# Wolfenstein 2: The New Colossus                   128                   87.0
# Wolfenstein: Youngblood                           115                   66.0
# Yakuza: Like a Dragon                             100                   86.0

# %%
#statistics

#number of critics reviews per game
mean_number_critics_reviews = np.mean(df_q2['critic_review'])
median_number_critics_reviews = np.median(df_q2['critic_review'])
std_number_critics_reviews = np.std(df_q2['critic_review'])
max_number_critics_reviews = max(df_q2['critic_review'])
min_number_critics_reviews = min(df_q2['critic_review'])

#critics average score
mean_critics_ave_score = np.mean(df_q2['critics_average_score'])
median_critics_ave_score = np.median(df_q2['critics_average_score'])
std_critics_ave_score = np.std(df_q2['critics_average_score'])
max_critics_ave_score = max(df_q2['critics_average_score'])
min_critics_ave_score = min(df_q2['critics_average_score'])

stats_table_1 = pd.DataFrame(data={
    'Mean':[round(mean_number_critics_reviews, 2), round(mean_critics_ave_score, 2)], 
    'Median': [median_number_critics_reviews, median_critics_ave_score],
    'Standard deviation': [round(std_number_critics_reviews, 2), round(std_critics_ave_score, 2)],
    'Maximum': [max_number_critics_reviews, max_critics_ave_score],
    'Minimum': [min_number_critics_reviews, min_critics_ave_score],
    }, index=['Number of reviews','critics average score'])

stats_table_1
# Out:
#                          Mean  Median  Standard deviation  Maximum  Minimum
# Number of reviews      117.32   117.0               12.91    150.0     93.0
# critics average score   81.40    83.0                7.60     95.0     53.0

# %% [markdown]
# Explain the reason why the mean critics score in the above code is different from the average critics score scraped from Opencritic (not all reviews considered in the above code as some reviews were scored using stars)

# %%
df_q2.loc[:,'critic_review'].values
# Out:
# array([113, 120, 119,  93, 103, 100, 106, 125, 124, 127, 120,  96, 116,
#        117, 130, 124, 104, 108, 130, 130, 129, 143, 115, 110, 134,  99,
#        101, 108, 133, 102, 100, 132, 131, 102, 113, 118, 118, 128, 122,
#        112, 120, 117, 117, 127, 120, 110, 117, 143, 150, 121,  95, 117,
#        134, 101, 128, 115, 100], dtype=int64)

# %%
#plot the boxplot for number of reviews and the average critic scores
#also plot the standardised form, with the mean and standard deviation displayed
#display the scatterplot comparing both variables

fig = plt.figure(figsize=(15,20))

gs = gridspec.GridSpec(3, 2)

ax1 = fig.add_subplot(gs[0,0])
ax2 = fig.add_subplot(gs[0,1])
ax3 = fig.add_subplot(gs[1,0])
ax4 = fig.add_subplot(gs[1,1])
ax5 = fig.add_subplot(gs[2,:])

#plot number of reviews per game
ax1.boxplot(x=df_q2['critic_review'])
ax1.set_title('Boxplot displaying the distribution of the number of reviews per game.')
ax1.set_ylabel('Number of reviews')
ax1.set_xticklabels('')

#plot critics_average_score
ax2.boxplot(x=df_q2['critics_average_score'])
ax2.set_title('Boxplot displaying the distribution of the critic\'s average score for each game.')
ax2.set_ylabel('Average critics score')
ax2.set_xticklabels('')

#normalise distributions using z-score
df_q2['normalise_critic_review'] = (df_q2['critic_review'] - mean_number_critics_reviews) / std_number_critics_reviews
df_q2['normalise_critics_average_score'] = (df_q2['critics_average_score'] - mean_critics_ave_score) /\
                                            std_critics_ave_score

#plot normalised distributions
ax3.hist(df_q2['normalise_critic_review'], bins=14, color='cornflowerblue')
ax3.set_title('Normalised histogram distribution for number of reviews\n per game around the mean (mean=0).')
ax3.set_xlabel('Number of standard deviations from the mean.')
ax3.set_ylabel('Frequency')
ax3.axvline(x=0, color='black', linestyle='--')

ax4.hist(df_q2['normalise_critics_average_score'], bins=14, color='gold')
ax4.set_title('Normalised histogram distribution for critics average score\n per game around the mean (mean=0).')
ax4.set_xlabel('Number of standard deviations from the mean.')
ax4.set_ylabel('Frequency')
ax4.axvline(x=0, color='black', linestyle='--')

#plot scatterplot comparing the two variables
ax5.scatter(df_q2['critics_average_score'], df_q2['critic_review'], color='orangered')
ax5.set_title('Scattergraph comparing the number of reviews per game with\n the critics average score for each game.')
ax5.set_xlabel('Critics average score')
ax5.set_ylabel('Number of reviews')
ax5.axvline(x=80, color='black', linestyle='--')
ax5.axhline(y=130, color='black', linestyle='--')

plt.tight_layout()
plt.show()

# %%
#calculated correlation coefficient for the two variables compared above in the scattergraph
corr_coef = np.corrcoef(x=df_q2['critics_average_score'], y=df_q2['critic_review'])
#corr_coef --> poor correlation between the two variables (0.1)

#however, there does appear to be some games that have a number of reviews > 130 but also a score > 80
#all games with average score < 80 have less than 130 reviews
#indicated by the horizontal and vertical dashed lines on the scatterplot

# %% [markdown]
# ## Research question 3:
#
# ### What are the top words used by critics when writing a review?

# %%
#make a copy of the original dataframe
df4 = df.copy()

#process the text (using function created earlier in the notebook) 
reviews = df4.loc[:,'critic_review']
tokenize_reviews = reviews.apply(lambda x: process_text(x))

#combine all reviews into one text
combined_text = []
for text in tokenize_reviews:
    combined_text.extend(text)
#combined_text

# %%
fdist = FreqDist(combined_text)
top_ten_words = fdist.most_common(11)

unzipped_top_ten_words = list(zip(*top_ten_words))
print(unzipped_top_ten_words)

#plot top ten words
plt.bar(unzipped_top_ten_words[0], unzipped_top_ten_words[1], color='plum')

plt.tight_layout()
# Out:
# [('game', 'one', 'new', 'story', 'series', 'best', 'world', 'time', 'like', 'experience', 'great'), (5612, 1501, 1390, 1237, 1177, 1150, 1089, 1070, 1064, 1032, 1026)]

# %% [markdown]
# ## Research question 4:
#
# ### What are the top words used by the critics for each publisher?

# %%
#df.publisher.nunique()
#33 different publisher --> to group by publisher in a new copy of df
df5 = df.copy()

#process text using process_text function
df5['publisher_new'] = df5['publisher'].apply(lambda x: process_word(x))

#explain the use of process_word (need for l and rstrip)
df5.publisher_new.nunique()
# Out:
# 25

# %%
#group the publishers
publishers_grouped = df5.groupby('publisher_new').critic_review.apply(lambda x: ' '.join(x))
publishers_grouped
# Out:
# publisher_new
# 505 games                                Control is set in an engrossingly weird parano...
# activision                               Gorgeous guns, a glittering universe, and a gr...
# bandai namco entertainment               Little Nightmares 2 delivers similar stealth a...
# bandai namco games                       Sprawling level design, thrilling combat, and ...
# bethesda softworks                       Vaster, magnetic and more brutal than ever, DO...
# bigben interactive                       While occasionally frustrating, The Sinking Ci...
# capcom                                   Resident Evil Village is a genuinely engrossin...
# deep silver                              Metro Exodus on the PlayStation 5 is more than...
# electronic arts                          Mass Effect: Andromeda only occasionally recap...
# focus home interactive                   Visually beautiful and emotionally affecting t...
# microsoft                                Unless you're looking for a hardcore sim, Forz...
# microsoft game studios                   A by-the-numbers campaign feels stuck in 2006,...
# nintendo                                 Donkey Kong: Tropical Freeze's addition of Fun...
# playstation                              Ghost of Tsushima is an excellent action game ...
# private division                         There's a category of games I think of as Satu...
# sega                                     Yakuza: Like a Dragon takes some bold steps in...
# sony                                     A classy sandbox that stands out from the pack...
# sony interactive entertainment           The Last of Us Part 2 is a masterpiece that ev...
# square enix                              Shadow of the Tomb Raider offers up a powerful...
# thq nordic                               Biomutant's stunning world barely survives the...
# tripwire interactive                     Maneater's monster-shark feeding frenzy is fun...
# ubisoft                                  Far Cry 5 is another wide-open playground with...
# warner bros interactive entertainment    It's impressive that Mortal Kombat 11 plays as...
# wb games                                 Cyberpunk 2077 is an unforgettable experience ...
# xbox game studios                        No matter which mode you approach it from, Gea...
# Name: critic_review, dtype: object

# %%
#process text
publishers_grouped = publishers_grouped.apply(lambda x: process_text(x))

publishers_grouped
# Out:
# publisher_new
# 505 games                                [control, set, engrossingly, weird, paranormal...
# activision                               [gorgeous, gun, glittering, universe, great, p...
# bandai namco entertainment               [little, nightmare, delivers, similar, stealth...
# bandai namco games                       [sprawling, level, design, thrilling, combat, ...
# bethesda softworks                       [vaster, magnetic, brutal, ever, doom, eternal...
# bigben interactive                       [occasionally, frustrating, sinking, city, com...
# capcom                                   [resident, evil, village, genuinely, engrossin...
# deep silver                              [metro, exodus, playstation, simple, upgrade, ...
# electronic arts                          [mass, effect, andromeda, occasionally, recapt...
# focus home interactive                   [visually, beautiful, emotionally, affecting, ...
# microsoft                                [unless, youre, looking, hardcore, sim, forza,...
# microsoft game studios                   [bythenumbers, campaign, feel, stuck, multipla...
# nintendo                                 [donkey, kong, tropical, freeze, addition, fun...
# playstation                              [ghost, tsushima, excellent, action, game, ope...
# private division                         [there, category, game, think, saturday, morni...
# sega                                     [yakuza, like, dragon, take, bold, step, new, ...
# sony                                     [classy, sandbox, stand, pack, thanks, brillia...
# sony interactive entertainment           [last, u, part, masterpiece, evolves, gameplay...
# square enix                              [shadow, tomb, raider, offer, powerful, finale...
# thq nordic                               [biomutants, stunning, world, barely, survives...
# tripwire interactive                     [maneaters, monstershark, feeding, frenzy, fun...
# ubisoft                                  [far, cry, another, wideopen, playground, nece...
# warner bros interactive entertainment    [impressive, mortal, kombat, play, well, switc...
# wb games                                 [cyberpunk, unforgettable, experience, huge, u...
# xbox game studios                        [matter, mode, approach, gear, incredibly, fun...
# Name: critic_review, dtype: object

# %%
#obtain top five words used for each publisher

top_5_words_publishers = publishers_grouped.apply(lambda x: dict(FreqDist(x).most_common(5)))
top_5_words_publishers
# Out:
# publisher_new
# 505 games                                {'control': 143, 'game': 117, 'remedy': 67, 'o...
# activision                               {'game': 698, 'call': 319, 'crash': 319, 'duty...
# bandai namco entertainment               {'game': 222, 'ball': 134, 'dragon': 133, 'lit...
# bandai namco games                       {'soul': 180, 'dark': 145, 'game': 88, 'iii': ...
# bethesda softworks                       {'game': 786, 'doom': 312, 'new': 256, 'wolfen...
# bigben interactive                       {'city': 122, 'sinking': 118, 'game': 114, 'st...
# capcom                                   {'evil': 183, 'resident': 181, 'village': 139,...
# deep silver                              {'metro': 139, 'exodus': 119, 'game': 91, 'wor...
# electronic arts                          {'game': 252, 'mass': 127, 'effect': 124, 'and...
# focus home interactive                   {'game': 195, 'tale': 121, 'plague': 116, 'cth...
# microsoft                                {'game': 131, 'forza': 118, 'horizon': 117, 'r...
# microsoft game studios                   {'gear': 161, 'war': 124, 'new': 60, 'game': 6...
# nintendo                                 {'freeze': 89, 'tropical': 88, 'kong': 81, 'do...
# playstation                              {'game': 130, 'tsushima': 129, 'ghost': 127, '...
# private division                         {'world': 159, 'outer': 144, 'game': 102, 'obs...
# sega                                     {'yakuza': 134, 'like': 114, 'dragon': 104, 's...
# sony                                     {'game': 237, 'mile': 138, 'spiderman': 135, '...
# sony interactive entertainment           {'game': 512, 'spiderman': 173, 'god': 171, 'w...
# square enix                              {'game': 258, 'tomb': 154, 'avenger': 142, 'ra...
# thq nordic                               {'game': 209, 'darksiders': 145, 'biomutant': ...
# tripwire interactive                     {'maneater': 116, 'game': 85, 'shark': 59, 'fu...
# ubisoft                                  {'game': 479, 'creed': 276, 'assassin': 276, '...
# warner bros interactive entertainment    {'game': 465, 'fighting': 176, 'hitman': 137, ...
# wb games                                 {'cyberpunk': 143, 'game': 115, 'one': 35, 'wo...
# xbox game studios                        {'gear': 148, 'game': 63, 'series': 46, 'new':...
# Name: critic_review, dtype: object

# %%
#plot top 5 words by publisher
top_5_words_vals = top_5_words_publishers.values
top_5_words_index = top_5_words_publishers.index
len(top_5_words_vals)

fig, ax = plt.subplots(5,5,figsize=(15,15))
ax = ax.flatten()

for i in range(len(top_5_words_publishers)):
    ax[i].bar(top_5_words_vals[i].keys(), top_5_words_vals[i].values(), color='coral')
    ax[i].set_title(top_5_words_index[i])
    ax[i].set_xticklabels(top_5_words_vals[i].keys(), rotation=45)

plt.tight_layout()
plt.show()

#top words use are indicative of the current games being discussed in the reviews
# Out:
# C:\Users\jimma\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   if sys.path[0] == '':

# %% [markdown]
# ## Research question 5:
#
# ### What are the most frequest words used for each rating category in opencritic?

# %% [markdown]
# The website categorises a game based on the average critics score:
#
# - Mighty: average critics score is 90th percentile or higher
# - Strong: avergae critics score between 60th and 90th percentile
# - Fair: average critics score between 30th and 60th percentile
# - Weak: average critics score is in the bottom 30th percentile
#
# Separate games into these four different categories and anaylse most frequent words used by applying to individual critics scores instead of the game's average critics score.

# %%
#use df2
df_q5 = df2.loc[:,['critic_review', 'critics_score']]

#don't require dropping null values as df2 has already dropped null values
#create function that categorises scores and apply to critics score

def categorise_scores(score):
    if score >= 90:
        return "mighty"
    elif score >= 60 and score < 90:
        return "strong"
    elif score >= 30 and score < 60:
        return "fair"
    else:
        return "weak"

#create new column for opencritic rating
df_q5['opencritic_rating'] = df_q5['critics_score'].apply(lambda x: categorise_scores(x))
df_q5
# Out:
#                                            critic_review  critics_score  \
# 0      There's a category of games I think of as Satu...           79.0
# 1      With The Outer Worlds, Obsidian has found its ...           85.0
# 3      A deep, funny, and intricately designed RPG re...           90.0
# 4      The Outer Worlds marks Obsidian operating at t...           90.0
# 6      Classic RPG sensibilities enhance wonderful ch...           93.0
# ...                                                  ...            ...
# 15080  Star Wars Battlefront 2 manages to make nearly...           40.0
# 15081  An engaging campaign, a satisfying arcade mode...           80.0
# 15083  Star Wars Battlefront II is a complete experie...           85.0
# 15084  I do really enjoy playing this, but when you l...           70.0
# 15085  So, does Star Wars Battlefront II fulfill the ...           65.0
#
#       opencritic_rating
# 0                strong
# 1                strong
# 3                mighty
# 4                mighty
# 6                mighty
# ...                 ...
# 15080              fair
# 15081            strong
# 15083            strong
# 15084            strong
# 15085            strong
#
# [6687 rows x 3 columns]

# %%
#group by opencritic_rating
ratings_grouped = df_q5.groupby('opencritic_rating').critic_review.apply(lambda x: ''.join(x))
ratings_grouped
# Out:
# opencritic_rating
# fair      The Outer Worlds is one of the most polished a...
# mighty    A deep, funny, and intricately designed RPG re...
# strong    There's a category of games I think of as Satu...
# weak      A disastrous failure whose technical shortcomi...
# Name: critic_review, dtype: object

# %%
#process the text before separating into the top words using process_text function

#process text
ratings_grouped = ratings_grouped.apply(lambda x: process_text(x))

ratings_grouped
# Out:
# opencritic_rating
# fair      [outer, world, one, polished, best, game, type...
# mighty    [deep, funny, intricately, designed, rpg, remi...
# strong    [there, category, game, think, saturday, morni...
# weak      [disastrous, failure, whose, technical, shortc...
# Name: critic_review, dtype: object

# %%
top_5_words_ratings = ratings_grouped.apply(lambda x: dict(FreqDist(x).most_common(5)))
top_5_words_ratings
# Out:
# opencritic_rating
# fair      {'game': 211, 'fallout': 77, 'world': 48, 'mak...
# mighty    {'game': 2159, 'one': 620, 'new': 575, 'best':...
# strong    {'game': 2971, 'one': 775, 'new': 772, 'story'...
# weak      {'game': 3, 'fallout': 3, 'whose': 2, 'may': 2...
# Name: critic_review, dtype: object

# %%
#plot the four ratings
top_5_words_ratings_vals = top_5_words_ratings.values
top_5_words_ratings_index = top_5_words_ratings.index

fig, ax = plt.subplots(2,2,figsize=(10,10))
ax = ax.flatten()

for i in range(len(top_5_words_ratings)):
    ax[i].bar(top_5_words_ratings_vals[i].keys(), top_5_words_ratings_vals[i].values(), color='coral')
    ax[i].set_title(top_5_words_ratings_index[i])
    ax[i].set_xticklabels(top_5_words_ratings_vals[i].keys(), rotation=45)
    
plt.show()
# Out:
# C:\Users\jimma\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   # This is added back by InteractiveShellApp.init_path()

# %%
#use ratings for classifying critics_reviews
df['opencritic_rating_critics_score'] = df['critics_score'].apply(lambda x: categorise_scores(x))
df
# Out:
#                             name               developer         publisher  \
# 0              The Outer Worlds   Obsidian Entertainment  Private Division
# 1              The Outer Worlds   Obsidian Entertainment  Private Division
# 3              The Outer Worlds   Obsidian Entertainment  Private Division
# 4              The Outer Worlds   Obsidian Entertainment  Private Division
# 6              The Outer Worlds   Obsidian Entertainment  Private Division
# ...                          ...                     ...               ...
# 15080   Star Wars Battlefront 2                   DICE,    Electronic Arts
# 15081   Star Wars Battlefront 2                   DICE,    Electronic Arts
# 15083   Star Wars Battlefront 2                   DICE,    Electronic Arts
# 15084   Star Wars Battlefront 2                   DICE,    Electronic Arts
# 15085   Star Wars Battlefront 2                   DICE,    Electronic Arts
#
#                                               genre release_date  \
# 0                                               RPG   2019-10-25
# 1                                               RPG   2019-10-25
# 3                                               RPG   2019-10-25
# 4                                               RPG   2019-10-25
# 6                                               RPG   2019-10-25
# ...                                             ...          ...
# 15080  Action, First-Person Shooter, Vehicle Combat   2017-11-17
# 15081  Action, First-Person Shooter, Vehicle Combat   2017-11-17
# 15083  Action, First-Person Shooter, Vehicle Combat   2017-11-17
# 15084  Action, First-Person Shooter, Vehicle Combat   2017-11-17
# 15085  Action, First-Person Shooter, Vehicle Combat   2017-11-17
#
#                                              description  \
# 0      The Outer Worlds is a new single-player first-...
# 1      The Outer Worlds is a new single-player first-...
# 3      The Outer Worlds is a new single-player first-...
# 4      The Outer Worlds is a new single-player first-...
# 6      The Outer Worlds is a new single-player first-...
# ...                                                  ...
# 15080  Embark on an all-new Battlefront experience fr...
# 15081  Embark on an all-new Battlefront experience fr...
# 15083  Embark on an all-new Battlefront experience fr...
# 15084  Embark on an all-new Battlefront experience fr...
# 15085  Embark on an all-new Battlefront experience fr...
#
#        critics_average_score  \
# 0                         82
# 1                         82
# 3                         82
# 4                         82
# 6                         82
# ...                      ...
# 15080                     68
# 15081                     68
# 15083                     68
# 15084                     68
# 15085                     68
#
#                                            critic_review       date_of_review  \
# 0      There's a category of games I think of as Satu...  2019-10-22 00:00:00
# 1      With The Outer Worlds, Obsidian has found its ...  2019-10-22 00:00:00
# 3      A deep, funny, and intricately designed RPG re...  2019-10-29 00:00:00
# 4      The Outer Worlds marks Obsidian operating at t...  2019-10-22 00:00:00
# 6      Classic RPG sensibilities enhance wonderful ch...  2019-10-22 00:00:00
# ...                                                  ...                  ...
# 15080  Star Wars Battlefront 2 manages to make nearly...  2017-11-24 00:00:00
# 15081  An engaging campaign, a satisfying arcade mode...  2017-11-25 00:00:00
# 15083  Star Wars Battlefront II is a complete experie...  2017-11-20 00:00:00
# 15084  I do really enjoy playing this, but when you l...  2017-11-21 00:00:00
# 15085  So, does Star Wars Battlefront II fulfill the ...  2017-11-19 00:00:00
#
#        critics_score opencritic_rating_critics_score
# 0               79.0                          strong
# 1               85.0                          strong
# 3               90.0                          mighty
# 4               90.0                          mighty
# 6               93.0                          mighty
# ...              ...                             ...
# 15080           40.0                            fair
# 15081           80.0                          strong
# 15083           85.0                          strong
# 15084           70.0                          strong
# 15085           65.0                          strong
#
# [6687 rows x 11 columns]

# %%
df.to_csv("opencritic_data_with_ratings.csv")
